# %% [markdown]
# # Task 1: Data Acquisition and Data Wrangling on dataset 1 and dataset 2
# [All methods to be applied for data wrangling concerning the listed above and
# combine_data from dataset1 and dataset2, Work on central tendency.  ]

# %% [markdown]
# Different methods for data wrangling:
# 1.   Merge datasets
# 2.   Identify unique values
# 3.   Drop unnecessary columns
# 4.   Check the dimensions of the dataset
# 5.   Check the datatype of the dataset
# 6.   Check datatype summary
# 7.   Treat missing values
# 8.   Validate the correctness of the data at the primary level if applicable

# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv(r'D:\DA Projects\2- Data Aquisition and Wrangling\datasets\dataset_1 - dataset_1.csv')
df2=pd.read_csv(r'D:\DA Projects\2- Data Aquisition and Wrangling\datasets\dataset_2.xlsx - dataset_2.csv')

# %%
df1.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
df1.shape
# Out:
# (610, 10)

# %%
df2.head()
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
df2.shape
# Out:
# (610, 8)

# %% [markdown]
# ### Merge datasets

# %%
combine_data=pd.merge(left=df1,right=df2,how='inner',on='instant')
combine_data.shape
# Out:
# (610, 17)

# %%
combine_data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp  Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24           0  0.2879  0.81        0.0       3          13   16
# 1  0.22           1  0.2727  0.80        0.0       8          32   40
# 2  0.22           2  0.2727  0.80        0.0       5          27   32
# 3  0.24           3  0.2879  0.75        0.0       3          10   13
# 4  0.24           4  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Identify unique values

# %%
combine_data.nunique()
# Out:
# instant       610
# dteday         28
# season          1
# yr              1
# mnth            1
# hr             24
# holiday         2
# weekday         7
# weathersit      4
# temp           23
# Unnamed: 0    610
# atemp          29
# hum            61
# windspeed      20
# casual         32
# registered    150
# cnt           165
# dtype: int64

# %% [markdown]
# ### Drop unnecessary columns

# %%
combine_data.drop(labels=['instant','season','yr','mnth','Unnamed: 0'],axis=1,inplace=True)

# %% [markdown]
# ### Check the dimensions of the dataset

# %%
combine_data.shape
# Out:
# (610, 12)

# %% [markdown]
# ### Check the datatype of the dataset

# %%
combine_data.dtypes
# Out:
# dteday         object
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# ### Check datatype summary

# %%
combine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dteday      610 non-null    object
#  1   hr          610 non-null    int64
#  2   holiday     610 non-null    bool
#  3   weekday     610 non-null    int64
#  4   weathersit  610 non-null    int64
#  5   temp        610 non-null    float64
#  6   atemp       599 non-null    float64
#  7   hum         610 non-null    float64
#  8   windspeed   610 non-null    float64
#  9   casual      610 non-null    int64
#  10  registered  610 non-null    int64
#  11  cnt         610 non-null    int64
# dtypes: bool(1), float64(4), int64(6), object(1)
# memory usage: 53.1+ KB

# %% [markdown]
# ### Treat missing values

# %%
combine_data.isnull().sum()
# Out:
# dteday         0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
combine_data['atemp']=combine_data['atemp'].fillna(combine_data['atemp'].mean())

# %%
combine_data
# Out:
#          dteday  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0    01-01-2011   0    False        6           1  0.24  0.2879  0.81
# 1    01-01-2011   1    False        6           1  0.22  0.2727  0.80
# 2    01-01-2011   2    False        6           1  0.22  0.2727  0.80
# 3    01-01-2011   3    False        6           1  0.24  0.2879  0.75
# 4    01-01-2011   4    False        6           1  0.24  0.2879  0.75
# ..          ...  ..      ...      ...         ...   ...     ...   ...
# 605  28-01-2011  11    False        5           3  0.18  0.2121  0.93
# 606  28-01-2011  12    False        5           3  0.18  0.2121  0.93
# 607  28-01-2011  13    False        5           3  0.18  0.2121  0.93
# 608  28-01-2011  14    False        5           3  0.22  0.2727  0.80
# 609  28-01-2011  15    False        5           2  0.20  0.2576  0.86
#
#      windspeed  casual  registered  cnt
# 0       0.0000       3          13   16
# 1       0.0000       8          32   40
# ...

# %%
combine_data.isnull().sum()
# Out:
# dteday        0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ### Validate the correctness of the data at the primary level if applicable

# %%
combine_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
combine_data['dteday']=pd.to_datetime(combine_data['dteday'],dayfirst=True,errors='coerce')

# %%
combine_data
# Out:
#         dteday  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0   2011-01-01   0    False        6           1  0.24  0.2879  0.81
# 1   2011-01-01   1    False        6           1  0.22  0.2727  0.80
# 2   2011-01-01   2    False        6           1  0.22  0.2727  0.80
# 3   2011-01-01   3    False        6           1  0.24  0.2879  0.75
# 4   2011-01-01   4    False        6           1  0.24  0.2879  0.75
# ..         ...  ..      ...      ...         ...   ...     ...   ...
# 605 2011-01-28  11    False        5           3  0.18  0.2121  0.93
# 606 2011-01-28  12    False        5           3  0.18  0.2121  0.93
# 607 2011-01-28  13    False        5           3  0.18  0.2121  0.93
# 608 2011-01-28  14    False        5           3  0.22  0.2727  0.80
# 609 2011-01-28  15    False        5           2  0.20  0.2576  0.86
#
#      windspeed  casual  registered  cnt
# 0       0.0000       3          13   16
# 1       0.0000       8          32   40
# ...

# %%
combine_data.describe()
# Out:
#                               dteday          hr     weekday  weathersit  \
# count                            610  610.000000  610.000000  610.000000
# mean   2011-01-13 19:47:24.590163968   11.795082    2.977049    1.477049
# min              2011-01-01 00:00:00    0.000000    0.000000    1.000000
# 25%              2011-01-07 00:00:00    6.000000    1.000000    1.000000
# 50%              2011-01-14 00:00:00   12.000000    3.000000    1.000000
# 75%              2011-01-21 00:00:00   18.000000    5.000000    2.000000
# max              2011-01-28 00:00:00   23.000000    6.000000    4.000000
# std                              NaN    6.852107    2.054943    0.643496
#
#              temp       atemp         hum   windspeed      casual  registered  \
# count  610.000000  610.000000  610.000000  610.000000  610.000000  610.000000
# mean     0.196885    0.199935    0.562475    0.204851    4.501639   51.068852
# ...

# %% [markdown]
# # Task 2: Data Acquisition and Wrangling on Dataset 3.
# Concatenate combine_ data with Dataset_3. To be Worked on missing values and
# outliers.-Week 2
# Check the skewness and correlation of the data.

# %% [markdown]
# ### Merge datasets

# %%
df3=pd.read_csv(r'D:\DA Projects\2- Data Aquisition and Wrangling\datasets\dataset_3 - dataset_3.csv')

# %%
df3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
df3.shape
# Out:
# (390, 16)

# %%
combine_data=pd.merge(left=df1,right=df2,how='inner',on='instant')
combine_data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp  Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24           0  0.2879  0.81        0.0       3          13   16
# 1  0.22           1  0.2727  0.80        0.0       8          32   40
# 2  0.22           2  0.2727  0.80        0.0       5          27   32
# 3  0.24           3  0.2879  0.75        0.0       3          10   13
# 4  0.24           4  0.2879  0.75        0.0       0           1    1

# %%
combine_data.drop(labels='Unnamed: 0',axis=1,inplace=True)

# %%
df3.shape
# Out:
# (390, 16)

# %%
combine_data.shape
# Out:
# (610, 16)

# %%
df=pd.concat(objs=[combine_data,df3],axis=0,join='inner')
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24  0.2879  0.81        0.0       3          13   16
# 1  0.22  0.2727  0.80        0.0       8          32   40
# 2  0.22  0.2727  0.80        0.0       5          27   32
# 3  0.24  0.2879  0.75        0.0       3          10   13
# 4  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.shape
# Out:
# (1000, 16)

# %% [markdown]
# ### Identify unique values

# %%
df.nunique()
# Out:
# instant       1000
# dteday          45
# season           1
# yr               1
# mnth             2
# hr              24
# holiday          2
# weekday          7
# weathersit       4
# temp            23
# atemp           30
# hum             64
# windspeed       20
# casual          42
# registered     186
# cnt            191
# dtype: int64

# %% [markdown]
# ### Drop unnecessary columns

# %%
df.drop(labels=['instant','season','yr','mnth'],axis=1,inplace= True)

# %%
df
# Out:
#          dteday  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0    01-01-2011   0    False        6           1  0.24  0.2879  0.81
# 1    01-01-2011   1    False        6           1  0.22  0.2727  0.80
# 2    01-01-2011   2    False        6           1  0.22  0.2727  0.80
# 3    01-01-2011   3    False        6           1  0.24  0.2879  0.75
# 4    01-01-2011   4    False        6           1  0.24  0.2879  0.75
# ..          ...  ..      ...      ...         ...   ...     ...   ...
# 385  28-01-2011  20    False        5           2  0.24  0.2273  0.70
# 386  28-01-2011  21    False        5           2  0.22  0.2273  0.75
# 387  28-01-2011  22    False        5           1  0.24  0.2121  0.65
# 388  28-01-2011  23    False        5           1  0.24  0.2273  0.60
# 389  29-01-2011   0    False        6           1  0.22  0.1970  0.64
#
#      windspeed  casual  registered  cnt
# 0       0.0000       3          13   16
# 1       0.0000       8          32   40
# ...

# %% [markdown]
# ### Check the dimensions of the dataset

# %%
df.shape
# Out:
# (1000, 12)

# %% [markdown]
# ### Check the datatype of the dataset

# %%
df.dtypes
# Out:
# dteday         object
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# ### Check datatype summary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 389
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dteday      1000 non-null   object
#  1   hr          1000 non-null   int64
#  2   holiday     1000 non-null   bool
#  3   weekday     1000 non-null   int64
#  4   weathersit  1000 non-null   int64
#  5   temp        1000 non-null   float64
#  6   atemp       989 non-null    float64
#  7   hum         1000 non-null   float64
#  8   windspeed   1000 non-null   float64
#  9   casual      1000 non-null   int64
#  10  registered  1000 non-null   int64
#  11  cnt         1000 non-null   int64
# dtypes: bool(1), float64(4), int64(6), object(1)
# memory usage: 94.7+ KB

# %% [markdown]
# ### Treat missing values

# %%
df.isnull().sum()
# Out:
# dteday         0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
df['atemp']=df['atemp'].fillna(value=df['atemp'].mean())

# %%
df.isnull().sum()
# Out:
# dteday        0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ### Validate the correctness of the data at the primary level if applicable

# %%
df.drop(labels='dteday',axis=1,inplace=True)

# %%
df[['atemp','hum']].corr()
# Out:
#           atemp       hum
# atemp  1.000000  0.193056
# hum    0.193056  1.000000

# %%
df.corr()
# Out:
#                   hr   holiday   weekday  weathersit      temp     atemp  \
# hr          1.000000 -0.005753  0.007531   -0.055802  0.203512  0.148537
# holiday    -0.005753  1.000000 -0.148682    0.165443 -0.059728 -0.072372
# weekday     0.007531 -0.148682  1.000000    0.060007 -0.081776 -0.052392
# weathersit -0.055802  0.165443  0.060007    1.000000  0.106041  0.137155
# temp        0.203512 -0.059728 -0.081776    0.106041  1.000000  0.912411
# atemp       0.148537 -0.072372 -0.052392    0.137155  0.912411  1.000000
# hum        -0.194853 -0.037542  0.062469    0.539402  0.080720  0.193056
# windspeed   0.116640 -0.001111 -0.056754   -0.177655  0.122625 -0.211758
# casual      0.204476 -0.000944 -0.047363   -0.096346  0.470221  0.423607
# registered  0.357042 -0.054350  0.020505   -0.119234  0.169045  0.137251
# cnt         0.366047 -0.051196  0.012161   -0.126448  0.229292  0.192437
#
#                  hum  windspeed    casual  registered       cnt
# ...

# %%
df.skew(axis=0)
# Out:
# hr           -0.063524
# holiday       6.229578
# weekday       0.021925
# weathersit    1.044098
# temp          0.547997
# atemp         0.430933
# hum           0.436893
# windspeed     0.433675
# casual        3.414105
# registered    1.296723
# cnt           1.137709
# dtype: float64
